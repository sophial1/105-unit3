# %% [markdown]
# ## Analyzing Data Sets
#
# Today you will learn to parse a large dataset and create a new dataset with a more concentrated focus. You will be analyzing County Health Data from 2014-2015 across the US, and the new consolidated data will have a focus on factors that influence youth mental health.
#
# You will follow a series of seven steps to go from a datset with thousands of rows and a diverse set of columns to a refined dataset centered around one issue in one location. You will be
#  1. Importing programs to help analyze the data,
#  2. Importing your dataset,
#  3. Looking through the data using basic functions,
#  4. Picking out specific rows for your subset,
#  5. Picking out specific columns for your subset,
#  6. Exporting your new, refined dataset,
#  7. And lastly guided through using the dataset.
#
# As a preliminary warning, you need to press "Command" and "Return" simultaneously on your keyboard to run a line of code.

# %% [markdown]
# #### Step 1: Importing Pandas and Numpy
#
# First, you need to import both Pandas, meant to help manage and sort your tabular data, and Numpy, which helps speed up the process of any larger calculations the program needs to run. These programs are included in your Anaconda/Python download.
#
# The programs can be imported using the `import` function, and you can rename the programs to something shorter by including `as`.
#
# As you import the packages you will also rename them, like this:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Step 2: Importing Your Dataset
#
# Your dataset must be in CSV form to upload it here. I am using CountyHealthData_2014-2015 (1).csv which is available at this link: https://uncch.instructure.com/courses/4844/files/1951168/download?download_frd=1.
#
# Use the function `pd.read_csv(name of document)` to upload the dataset and titled it "df". It should look like this:

# %%
df=pd.read_csv("CountyHealthData_2014-2015 (1).csv")

# %% [markdown]
# #### Step 3: Taking a Look at the Data
#
# To start looking at the data, it is important to understand what variables and categories you are working with. You will begin exploring the data by looking at the column and row labels, not the actually numbers yet.
#
# In general, you will explore aspects of the dataset using `df.` or `df[]` notation, with more specific examples below.
#
# Let's start by looking at `df.columns`, the types of columns you're working with. Run the program like this:

# %%
df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
#        'Severe housing problems', 'Driving alone to work',
#        'Long commute - driving alone', '2011 population estimate',
#        'Population that is not proficient in English',
#        'Population living in a rural area', 'Diabetes', 'HIV prevalence rate',
#        'Premature age-adjusted mortality', 'Infant mortality',
#        'Child mortality', 'Food insecurity', 'Limited access to healthy foods',
#        'Motor vehicle crash deaths', 'Drug poisoning deaths',
#        'Uninsured adults', 'Uninsured children', 'Health care costs',
#        'Could not see doctor due to cost', 'Other primary care providers',
#        'Median household income', 'Children eligible for free lunch',
#        'Homicide rate', 'Inadequate social support'],
#       dtype='object')

# %% [markdown]
# There's a lot of different kinds of variables in the dataset, including anything from healthcare to level of education. Take a second to read through the columns and see if there's any areas that intrigue you.
#
# Next, let's make sure this data encompasses all 50 states. Run `df.State`, like this:

# %%
df.State
# Out:
# 0       AK
# 1       AK
# 2       AK
# 3       AK
# 4       AK
#         ..
# 6104    WY
# 6105    WY
# 6106    WY
# 6107    WY
# 6108    WY
# Name: State, Length: 6109, dtype: object

# %% [markdown]
# It seems that there are duplicates of each state, let's find the unique values of the states using the `drop_duplicates` function. It should look like this:

# %%
df.drop_duplicates("State")
# Out:
#      State     Region            Division                      County   FIPS  \
# 0       AK       West             Pacific  Aleutians West Census Area   2016
# 46      AL      South  East South Central              Autauga County   1001
# 180     AR      South  West South Central             Arkansas County   5001
# 330     AZ       West            Mountain               Apache County   4001
# 360     CA       West             Pacific              Alameda County   6001
# 474     CO       West            Mountain                Adams County   8001
# 593     CT  Northeast         New England            Fairfield County   9001
# 609     DC      South      South Atlantic        District of Columbia  11001
# 610     DE      South      South Atlantic                 Kent County  10001
# 616     FL      South      South Atlantic              Alachua County  12001
# 750     GA      South      South Atlantic              Appling County  13001
# 1068    HI       West             Pacific               Hawaii County  15001
# 1076    IA    Midwest  West North Central                Adair County  19001
# 1274    ID       West            Mountain                  Ada County  16001
# 1358    IL    Midwest  East North Central                Adams County  17001
# 1562    IN    Midwest  East North Central                Adams County  18001
# 1746    KS    Midwest  West North Central                Allen County  20001
# 1945    KY      South  East South Central                Adair County  21001
# 2185    LA      South  West South Central               Acadia Parish  22001
# 2313    MA  Northeast         New England           Barnstable County  25001
# 2341    MD      South      South Atlantic             Allegany County  24001
# 2389    ME  Northeast         New England         Androscoggin County  23001
# 2421    MI    Midwest  East North Central               Alcona County  26001
# 2585    MN    Midwest  West North Central               Aitkin County  27001
# 2759    MO    Midwest  West North Central                Adair County  29001
# 2988    MS      South  East South Central                Adams County  28001
# 3151    MT       West            Mountain           Beaverhead County  30001
# 3243    NC      South      South Atlantic             Alamance County  37001
# 3443    ND    Midwest  West North Central                Adams County  38001
# 3535    NE    Midwest  West North Central                Adams County  31001
# 3692    NH  Northeast         New England              Belknap County  33001
# 3712    NJ  Northeast        Mid-Atlantic             Atlantic County  34001
# 3754    NM       West            Mountain           Bernalillo County  35001
# 3818    NV       West            Mountain                 Carson City  32510
# 3850    NY  Northeast        Mid-Atlantic               Albany County  36001
# 3974    OH    Midwest  East North Central                Adams County  39001
# 4150    OK      South  West South Central                Adair County  40001
# 4304    OR       West             Pacific                Baker County  41001
# 4371    PA  Northeast        Mid-Atlantic                Adams County  42001
# 4505    RI  Northeast         New England              Bristol County  44001
# 4515    SC      South      South Atlantic            Abbeville County  45001
# 4607    SD    Midwest  West North Central               Aurora County  46003
# 4724    TN      South  East South Central             Anderson County  47001
# 4914    TX      South  West South Central             Anderson County  48001
# 5383    UT       West            Mountain               Beaver County  49001
# 5437    VA      South      South Atlantic             Accomack County  51001
# 5703    VT  Northeast         New England              Addison County  50001
# 5731    WA       West             Pacific                Adams County  53001
# 5809    WI    Midwest  East North Central                Adams County  55001
# 5953    WV      South      South Atlantic              Barbour County  54001
# 6063    WY       West            Mountain               Albany County  56001
#
#       GEOID   SMS Region      Year  Premature death  Poor or fair health  ...  \
# 0      2016  Insuff Data  1/1/2014              NaN                0.122  ...
# 46     1001    Region 16  1/1/2014           8376.0                0.228  ...
# 180    5001    Region 11  1/1/2014          11046.0                0.287  ...
# 330    4001  Insuff Data  1/1/2014          14039.0                0.203  ...
# 360    6001    Region 26  1/1/2014           5141.0                0.145  ...
# 474    8001    Region 21  1/1/2014           6371.0                0.166  ...
# 593    9001    Region 12  1/1/2014           4541.0                0.100  ...
# 609   11001     Region 1  1/1/2015           8239.0                0.122  ...
# 610   10001    Region 23  1/1/2014           8338.0                0.147  ...
# 616   12001    Region 15  1/1/2014           7187.0                0.146  ...
# 750   13001    Region 15  1/1/2014          11116.0                0.239  ...
# 1068  15001    Region 18  1/1/2014           6853.0                0.149  ...
# 1076  19001  Insuff Data  1/1/2014           6621.0                0.087  ...
# 1274  16001    Region 28  1/1/2014           5007.0                0.120  ...
# 1358  17001     Region 6  1/1/2014           6328.0                0.190  ...
# 1562  18001  Insuff Data  1/1/2014           6806.0                0.133  ...
# 1746  20001  Insuff Data  1/1/2014           8766.0                0.189  ...
# 1945  21001     Region 5  1/1/2014           7968.0                0.318  ...
# 2185  22001    Region 19  1/1/2014          11697.0                0.204  ...
# 2313  25001    Region 12  1/1/2014           5861.0                0.083  ...
# 2341  24001     Region 1  1/1/2014           7375.0                0.175  ...
# 2389  23001    Region 12  1/1/2014           6148.0                0.134  ...
# 2421  26001     Region 7  1/1/2014          10875.0                0.128  ...
# 2585  27001     Region 9  1/1/2014           6611.0                0.169  ...
# 2759  29001    Region 25  1/1/2014           6630.0                0.175  ...
# 2988  28001    Region 19  1/1/2014          11907.0                0.231  ...
# 3151  30001  Insuff Data  1/1/2014           6265.0                0.110  ...
# 3243  37001    Region 20  1/1/2014           7123.0                0.192  ...
# 3443  38001  Insuff Data  1/1/2014              NaN                0.130  ...
# 3535  31001  Insuff Data  1/1/2014           6706.0                0.127  ...
# 3692  33001    Region 12  1/1/2014           6086.0                0.123  ...
# 3712  34001    Region 23  1/1/2014           7755.0                0.184  ...
# 3754  35001     Region 8  1/1/2014           7466.0                0.143  ...
# 3818  32510    Region 26  1/1/2014           7390.0                0.177  ...
# 3850  36001    Region 14  1/1/2014           6004.0                0.129  ...
# 3974  39001    Region 27  1/1/2014          10788.0                0.196  ...
# 4150  40001    Region 11  1/1/2014          11129.0                0.229  ...
# 4304  41001  Insuff Data  1/1/2014          10322.0                0.111  ...
# 4371  42001    Region 23  1/1/2014           5837.0                0.130  ...
# 4505  44001    Region 12  1/1/2014           4543.0                0.087  ...
# 4515  45001    Region 20  1/1/2014           7632.0                0.199  ...
# 4607  46003  Insuff Data  1/1/2015              NaN                0.134  ...
# 4724  47001     Region 5  1/1/2014           8831.0                0.194  ...
# 4914  48001    Region 10  1/1/2014          10526.0                0.213  ...
# 5383  49001    Region 28  1/1/2014           7991.0                0.138  ...
# 5437  51001     Region 1  1/1/2014           9240.0                0.200  ...
# 5703  50001    Region 14  1/1/2014           5113.0                0.091  ...
# 5731  53001    Region 22  1/1/2014           7210.0                0.233  ...
# 5809  55001  Insuff Data  1/1/2014           7413.0                0.149  ...
# 5953  54001    Region 27  1/1/2014           8475.0                0.241  ...
# 6063  56001  Insuff Data  1/1/2014           5279.0                0.102  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
#
# 0                         0.287
# 46                        0.237
# 180                       0.246
# 330                       0.366
# 360                       0.260
# 474                       0.193
# 593                       0.193
# 609                         NaN
# 610                       0.187
# 616                       0.207
# 750                         NaN
# 1068                      0.237
# 1076                      0.156
# 1274                      0.141
# 1358                      0.150
# 1562                      0.236
# 1746                      0.143
# 1945                      0.275
# 2185                      0.265
# 2313                      0.154
# 2341                      0.193
# 2389                      0.184
# 2421                      0.240
# 2585                      0.142
# 2759                      0.185
# 2988                      0.303
# 3151                      0.152
# 3243                      0.202
# 3443                      0.149
# 3535                      0.175
# 3692                      0.165
# 3712                      0.230
# 3754                      0.180
# 3818                      0.238
# 3850                      0.203
# 3974                        NaN
# 4150                      0.216
# 4304                      0.140
# 4371                      0.169
# 4505                      0.197
# 4515                      0.288
# 4607                        NaN
# 4724                      0.172
# 4914                      0.303
# 5383                      0.134
# 5437                      0.222
# 5703                      0.153
# 5731                      0.251
# 5809                      0.196
# 5953                      0.206
# 6063                      0.132
#
# [51 rows x 64 columns]

# %% [markdown]
# Now we know there are 51 rows of states (all 50 and the District of Columbia), and also what row ranges each state occupies.

# %% [markdown]
# #### Step 4: Selecting the Rows
#
# With our new general knowledge of the rows and columns, it's time to whittle down how much data there is to consume. You should focus on a specific state, for example Nevada.
#
# There are two ways to look at NV-specific data.
#
# The first is looking at all the rows that include the value "NV" in the "State" column. You will use the true/false statement `df[df["column title"] == "row value"]` to describe parts of the data you want to include, that being all rows with "NV" in them. The function will look like this:

# %%
df[df["State"] == "NV"]
# Out:
#      State Region  Division             County   FIPS  GEOID   SMS Region  \
# 3818    NV   West  Mountain        Carson City  32510  32510    Region 26
# 3819    NV   West  Mountain        Carson City  32510  32510    Region 26
# 3820    NV   West  Mountain   Churchill County  32001  32001  Insuff Data
# 3821    NV   West  Mountain   Churchill County  32001  32001  Insuff Data
# 3822    NV   West  Mountain       Clark County  32003  32003    Region 28
# 3823    NV   West  Mountain       Clark County  32003  32003    Region 28
# 3824    NV   West  Mountain     Douglas County  32005  32005    Region 26
# 3825    NV   West  Mountain     Douglas County  32005  32005    Region 26
# 3826    NV   West  Mountain        Elko County  32007  32007  Insuff Data
# 3827    NV   West  Mountain        Elko County  32007  32007  Insuff Data
# 3828    NV   West  Mountain      Eureka County  32011  32011  Insuff Data
# 3829    NV   West  Mountain      Eureka County  32011  32011  Insuff Data
# 3830    NV   West  Mountain    Humboldt County  32013  32013  Insuff Data
# 3831    NV   West  Mountain    Humboldt County  32013  32013  Insuff Data
# 3832    NV   West  Mountain      Lander County  32015  32015  Insuff Data
# 3833    NV   West  Mountain      Lander County  32015  32015  Insuff Data
# 3834    NV   West  Mountain     Lincoln County  32017  32017  Insuff Data
# 3835    NV   West  Mountain     Lincoln County  32017  32017  Insuff Data
# 3836    NV   West  Mountain        Lyon County  32019  32019    Region 26
# 3837    NV   West  Mountain        Lyon County  32019  32019    Region 26
# 3838    NV   West  Mountain     Mineral County  32021  32021  Insuff Data
# 3839    NV   West  Mountain     Mineral County  32021  32021  Insuff Data
# 3840    NV   West  Mountain         Nye County  32023  32023    Region 28
# 3841    NV   West  Mountain         Nye County  32023  32023    Region 28
# 3842    NV   West  Mountain    Pershing County  32027  32027  Insuff Data
# 3843    NV   West  Mountain    Pershing County  32027  32027  Insuff Data
# 3844    NV   West  Mountain      Storey County  32029  32029    Region 26
# 3845    NV   West  Mountain      Storey County  32029  32029    Region 26
# 3846    NV   West  Mountain      Washoe County  32031  32031    Region 26
# 3847    NV   West  Mountain      Washoe County  32031  32031    Region 26
# 3848    NV   West  Mountain  White Pine County  32033  32033  Insuff Data
# 3849    NV   West  Mountain  White Pine County  32033  32033  Insuff Data
#
#           Year  Premature death  Poor or fair health  ...  \
# 3818  1/1/2014           7390.0                0.177  ...
# 3819  1/1/2015           7511.0                0.177  ...
# 3820  1/1/2014           8757.0                0.136  ...
# 3821  1/1/2015           8979.0                0.136  ...
# 3822  1/1/2014           7168.0                0.179  ...
# 3823  1/1/2015           6933.0                0.179  ...
# 3824  1/1/2014           6125.0                0.148  ...
# 3825  1/1/2015           5176.0                0.148  ...
# 3826  1/1/2014           7291.0                0.181  ...
# 3827  1/1/2015           7175.0                0.181  ...
# 3828  1/1/2014              NaN                  NaN  ...
# 3829  1/1/2015              NaN                  NaN  ...
# 3830  1/1/2014           8758.0                0.145  ...
# 3831  1/1/2015           9382.0                0.145  ...
# 3832  1/1/2014           9695.0                0.169  ...
# 3833  1/1/2015           9522.0                0.169  ...
# 3834  1/1/2014           5317.0                0.121  ...
# 3835  1/1/2015           5942.0                0.121  ...
# 3836  1/1/2014           7103.0                0.161  ...
# 3837  1/1/2015           7949.0                0.161  ...
# 3838  1/1/2014          10373.0                0.191  ...
# 3839  1/1/2015          12736.0                0.191  ...
# 3840  1/1/2014          12332.0                0.198  ...
# 3841  1/1/2015          12023.0                0.198  ...
# 3842  1/1/2014           7720.0                0.190  ...
# 3843  1/1/2015           7061.0                0.190  ...
# 3844  1/1/2014           4299.0                0.158  ...
# 3845  1/1/2015           5891.0                0.158  ...
# 3846  1/1/2014           7100.0                0.153  ...
# 3847  1/1/2015           6962.0                0.153  ...
# 3848  1/1/2014           9773.0                0.201  ...
# 3849  1/1/2015          10954.0                0.201  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 3818                  19.03             0.264               0.167
# 3819                  17.56             0.271               0.170
# 3820                  20.74             0.240               0.171
# 3821                  24.74             0.259               0.179
# 3822                  19.39             0.275               0.155
# 3823                  20.44             0.285               0.165
# 3824                  17.97             0.208               0.167
# 3825                  19.44             0.216               0.166
# 3826                   8.87             0.241               0.180
# 3827                  11.50             0.239               0.159
# 3828                    NaN             0.192               0.182
# 3829                    NaN             0.220               0.184
# 3830                  12.75             0.259               0.200
# 3831                  17.60             0.268               0.191
# 3832                    NaN             0.223               0.159
# 3833                    NaN             0.223               0.161
# 3834                    NaN             0.266               0.233
# 3835                    NaN             0.277               0.230
# 3836                  13.28             0.260               0.160
# 3837                  14.14             0.286               0.182
# 3838                  32.51             0.251               0.170
# 3839                  36.02             0.253               0.172
# 3840                  29.98             0.253               0.166
# 3841                  31.71             0.276               0.171
# 3842                    NaN             0.282               0.254
# 3843                    NaN             0.270               0.209
# 3844                    NaN             0.223               0.215
# 3845                    NaN             0.243               0.205
# 3846                  19.59             0.268               0.187
# 3827                        NaN
# 3828                        NaN
# 3829                        NaN
# 3830                      0.252
# 3831                        NaN
# 3832                      0.202
# 3833                        NaN
# 3834                        NaN
# 3835                        NaN
# 3836                      0.238
# 3837                        NaN
# 3838                      0.300
# 3839                        NaN
# 3840                      0.256
# 3841                        NaN
# 3842                      0.219
# 3843                        NaN
# 3844                      0.178
# 3845                        NaN
# 3846                      0.217
# 3847                        NaN
# 3848                      0.280
# 3849                        NaN
#
# [32 rows x 64 columns]

# %% [markdown]
# You can also recall what range of rows are NV-specific, according to the states table from step 3, using the `df.iloc[range of rows, range of columns]` function.

# %%
df.iloc[3818:3850,:]
# Out:
#      State Region  Division             County   FIPS  GEOID   SMS Region  \
# 3818    NV   West  Mountain        Carson City  32510  32510    Region 26
# 3819    NV   West  Mountain        Carson City  32510  32510    Region 26
# 3820    NV   West  Mountain   Churchill County  32001  32001  Insuff Data
# 3821    NV   West  Mountain   Churchill County  32001  32001  Insuff Data
# 3822    NV   West  Mountain       Clark County  32003  32003    Region 28
# 3823    NV   West  Mountain       Clark County  32003  32003    Region 28
# 3824    NV   West  Mountain     Douglas County  32005  32005    Region 26
# 3825    NV   West  Mountain     Douglas County  32005  32005    Region 26
# 3826    NV   West  Mountain        Elko County  32007  32007  Insuff Data
# 3827    NV   West  Mountain        Elko County  32007  32007  Insuff Data
# 3828    NV   West  Mountain      Eureka County  32011  32011  Insuff Data
# 3829    NV   West  Mountain      Eureka County  32011  32011  Insuff Data
# 3830    NV   West  Mountain    Humboldt County  32013  32013  Insuff Data
# 3831    NV   West  Mountain    Humboldt County  32013  32013  Insuff Data
# 3832    NV   West  Mountain      Lander County  32015  32015  Insuff Data
# 3833    NV   West  Mountain      Lander County  32015  32015  Insuff Data
# 3834    NV   West  Mountain     Lincoln County  32017  32017  Insuff Data
# 3835    NV   West  Mountain     Lincoln County  32017  32017  Insuff Data
# 3836    NV   West  Mountain        Lyon County  32019  32019    Region 26
# 3837    NV   West  Mountain        Lyon County  32019  32019    Region 26
# 3838    NV   West  Mountain     Mineral County  32021  32021  Insuff Data
# 3839    NV   West  Mountain     Mineral County  32021  32021  Insuff Data
# 3840    NV   West  Mountain         Nye County  32023  32023    Region 28
# 3841    NV   West  Mountain         Nye County  32023  32023    Region 28
# 3842    NV   West  Mountain    Pershing County  32027  32027  Insuff Data
# 3843    NV   West  Mountain    Pershing County  32027  32027  Insuff Data
# 3844    NV   West  Mountain      Storey County  32029  32029    Region 26
# 3845    NV   West  Mountain      Storey County  32029  32029    Region 26
# 3846    NV   West  Mountain      Washoe County  32031  32031    Region 26
# 3847    NV   West  Mountain      Washoe County  32031  32031    Region 26
# 3848    NV   West  Mountain  White Pine County  32033  32033  Insuff Data
# 3849    NV   West  Mountain  White Pine County  32033  32033  Insuff Data
#
#           Year  Premature death  Poor or fair health  ...  \
# 3818  1/1/2014           7390.0                0.177  ...
# 3819  1/1/2015           7511.0                0.177  ...
# 3820  1/1/2014           8757.0                0.136  ...
# 3821  1/1/2015           8979.0                0.136  ...
# 3822  1/1/2014           7168.0                0.179  ...
# 3823  1/1/2015           6933.0                0.179  ...
# 3843             7805.0                             0.120
# 3844             7077.0                             0.172
# 3845             8501.0                             0.172
# 3846             8196.0                             0.152
# 3847             7974.0                             0.152
# 3848             8625.0                             0.152
# 3849             8098.0                             0.152
#
#       Other primary care providers  Median household income  \
# 3818                          67.0                    48227
# 3819                          68.0                    47476
# 3820                          57.0                    49463
# 3821                          58.0                    50158
# 3822                          38.0                    49583
# 3823                          43.0                    51071
# 3824                          55.0                    60869
# 3825                          57.0                    56613
# 3826                          37.0                    68759
# 3827                          38.0                    71354
# 3828                         150.0                    62864
# 3829                         241.0                    66592
# 3830                          23.0                    63772
# 3831                          23.0                    66290
# 3832                          17.0                    67424
# 3833                          50.0                    69658
# 3834                          74.0                    43617
# 3835                          76.0                    44366
# 3836                          31.0                    48035
# 3837                          37.0                    46526
# 3838                          64.0                    40308
# 3839                          65.0                    40496
# 3840                          61.0                    41426
# 3841                          69.0                    42998
# 3842                          44.0                    45192
# 3843                          44.0                    51548
# 3844                           NaN                    53471
# 3845                          25.0                    59785
# 3846                          59.0                    49449
# 3847                          62.0                    53565
# 3848                          10.0                    50417
# 3849                          10.0                    52588
#
#       Children eligible for free lunch  Homicide rate  \
# 3818                             0.375            NaN
# 3819                             0.170            NaN
# 3820                             0.346            NaN
# 3821                             0.377            NaN
# 3822                             0.462           8.03
# 3823                             0.513           6.60
# 3824                             0.277            NaN
# 3825                             0.293            NaN
# 3826                             0.253            NaN
# 3827                             0.257           3.30
# 3828                             0.172            NaN
# 3829                             0.190            NaN
# 3830                             0.312           9.11
# 3831                             0.297          10.00
# 3832                             0.209            NaN
# 3833                             0.207            NaN
# 3834                             0.356            NaN
# 3835                             0.372            NaN
# 3836                             0.360            NaN
# 3837                             0.376           4.30
# 3838                             0.410            NaN
# 3839                             0.404            NaN
# 3840                             0.488           6.40
# 3841                             0.468           7.10
# 3842                             0.601            NaN
# 3843                             0.599            NaN
# 3844                             0.035            NaN
# 3845                             0.042            NaN
# 3846                             0.393           5.21
# 3847                             0.386           5.10
# 3848                             0.251            NaN
# 3849                             0.267            NaN
#
#       Inadequate social support
# 3818                      0.238
# 3819                        NaN
# 3820                      0.231
# 3821                        NaN
# 3822                      0.235
# 3823                        NaN
# 3824                      0.170
# 3825                        NaN
# 3826                      0.231
# 3827                        NaN
# 3828                        NaN
# 3829                        NaN
# 3830                      0.252
# 3831                        NaN
# 3832                      0.202
# 3833                        NaN
# 3834                        NaN
# 3835                        NaN
# 3836                      0.238
# 3837                        NaN
# 3838                      0.300
# 3839                        NaN
# 3840                      0.256
# 3841                        NaN
# 3842                      0.219
# 3843                        NaN
# 3844                      0.178
# 3845                        NaN
# 3846                      0.217
# 3847                        NaN
# 3848                      0.280
# 3849                        NaN
#
# [32 rows x 64 columns]

# %% [markdown]
# There are still a lot of rows to handle here, so let's refine it even more to include just the city of Las Vegas and its close surroundings, that county being Clark County. We will use the `.iloc` function again, this time only bringing up a few rows. Your function will look like this:

# %%
df.iloc[3822:3824,:]
# Out:
#      State Region  Division        County   FIPS  GEOID SMS Region      Year  \
# 3822    NV   West  Mountain  Clark County  32003  32003  Region 28  1/1/2014
# 3823    NV   West  Mountain  Clark County  32003  32003  Region 28  1/1/2015
#
#       Premature death  Poor or fair health  ...  Drug poisoning deaths  \
# 3822           7168.0                0.179  ...                  19.39
# 3823           6933.0                0.179  ...                  20.44
#
#       Uninsured adults  Uninsured children  Health care costs  \
# 3822             0.275               0.155            10712.0
# 3823             0.285               0.165            10901.0
#
#       Could not see doctor due to cost  Other primary care providers  \
# 3822                             0.164                          38.0
# 3823                             0.164                          43.0
#
#       Median household income  Children eligible for free lunch  \
# 3822                    49583                             0.462
# 3823                    51071                             0.513
#
#       Homicide rate  Inadequate social support
# 3822           8.03                      0.235
# 3823           6.60                        NaN
#
# [2 rows x 64 columns]

# %% [markdown]
# #### Step 5: Selecting the Columns
#
# You can parse the data even further by specifying which columns of data you want included. Let's focus on data about youth mental health and factors that may contribute to that.
#
# It is easiest to recall the names of each column instead of it's number in the list, so let's use that information and the `df.loc[range of rows, strings of each specific column name]` function to create a new table.
#
# It is a long function, but it should look like this:

# %%
df.loc[3822:3823,["State","County","Physical inactivity","Excessive drinking","Children in poverty","Children in single-parent households","Food insecurity","Inadequate social support"]]
# Out:
#      State        County  Physical inactivity  Excessive drinking  \
# 3822    NV  Clark County                0.237               0.174
# 3823    NV  Clark County                0.217               0.174
#
#       Children in poverty  Children in single-parent households  \
# 3822                0.237                                 0.361
# 3823                0.237                                 0.372
#
#       Food insecurity  Inadequate social support
# 3822            0.174                      0.235
# 3823            0.157                        NaN

# %% [markdown]
# This digestable table features some of the most prominent factors in youth mental health crises while also highlighting access to resources to overcome mental health challenges.

# %% [markdown]
# #### Step 6: Exporting the Data Subset
#
# The last part of the process is to label the final version of your table, remove the index numbers, and export the file as a CSV. You will do so in two steps.
#
# First, perform the function `=` to create a name for the table like this:

# %%
CCMH_subset = df.loc[3822:3824,["State","County","Physical inactivity","Excessive drinking","Children in poverty","Children in single-parent households","Food insecurity","Inadequate social support"]].copy()

# %% [markdown]
# You can check your work by recalling the new title of the subset, like this:

# %%
CCMH_subset
# Out:
#      State          County  Physical inactivity  Excessive drinking  \
# 3822    NV    Clark County                0.237               0.174
# 3823    NV    Clark County                0.217               0.174
# 3824    NV  Douglas County                0.167               0.209
#
#       Children in poverty  Children in single-parent households  \
# 3822                0.237                                 0.361
# 3823                0.237                                 0.372
# 3824                0.160                                 0.291
#
#       Food insecurity  Inadequate social support
# 3822            0.174                      0.235
# 3823            0.157                        NaN
# 3824            0.147                      0.170

# %% [markdown]
# Then use `.to_csv(title for file)` to export it and add the qualification `index=False` to get rid of the now arbitrary row numbers. Your export function combined with the qualification function will look like this:

# %%
CCMH_subset.to_csv("CCMH_subset.csv", index=False)

# %% [markdown]
# #### Step 7: Guidance for Using Your Data Subset
#
# This specific subset of data consolidates certain statistics that contribute to mental health and youth populations specifically. It is important to note that this is data collected separately: it does not speak to a causal relationship in these factors, but it may lend itself to certain correlations.
#
# Lastly, when dealing with topics about mental health, it is important to realize the people and stories behind the numbers. This refined data table and others you may extract from this data are only a piece of the puzzle of mental health.

# %% [markdown]
# ## Try it Yourself!
#
# Use the space down here to try and replicate the code from before for practice, or create your own table in the state of your preference with even more columns to cover the topic!
